# %%
import json
import pandas as pd

# %%
with open (r"C:\Users\tjrai\Desktop\my_spotify_data\MyData\Playlist1.json", encoding = 'utf-8') as f:
    data = json.load(f)
    
    print(data)
# Out:
# {'playlists': [{'name': 'Daily Mix 1 - MADE FOR TJRAIDER23:4/28/19', 'lastModifiedDate': '2019-04-29', 'items': [{'track': {'trackName': 'Barbecue', 'artistName': 'Young Nudy', 'albumName': 'Nudy Land'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Mojo Jojo', 'artistName': 'UnoTheActivist', 'albumName': 'Live.Shyne.Die'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Talk To Big', 'artistName': 'Dave East', 'albumName': 'P2'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'GG', 'artistName': 'YoungBoy Never Broke Again', 'albumName': 'AI YoungBoy'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Look Like', 'artistName': 'Yung Pinch', 'albumName': '714Ever'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Icey', 'artistName': 'Young Thug', 'albumName': 'On the Run'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Same Yung Nigga (feat. Playboi Carti)', 'artistName': 'Gunna', 'albumName': 'Drip or Drown 2'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Cracks & Crevices', 'artistName': 'SahBabii', 'albumName': 'S.A.N.D.A.S.'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Middle Of The Summer (feat. Red Coldhearted)', 'artistName': 'Playboi Carti', 'albumName': 'Die Lit'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': "I'm The Mac", 'artistName': 'Lil Yachty', 'albumName': "Nuthin' 2 Prove"}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Activated', 'artistName': 'Tee Grizzley', 'albumName': 'Activated'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Givin out Smoke', 'artistName': 'Fredo Santana', 'albumName': "Trappin' Ain't Dead"}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Blank Blank', 'artistName': 'DaBaby', 'albumName': 'Blank Blank'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Russian Cream', 'artistName': 'Key Glock', 'albumName': 'Glock Bond'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'No More / No Way at All - Interlude', 'artistName': 'YFN Lucci', 'albumName': 'Ray Ray from Summerhill'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'White Girl', 'artistName': 'Shy Glizzy', 'albumName': 'Young Jefe'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': "Ballin'", 'artistName': 'Chief Keef', 'albumName': 'Finally Rich'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Cuttin Up', 'artistName': 'Lud Foe', 'albumName': 'Cuttin Up'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Battle Cry', 'artistName': 'Polo G', 'albumName': 'Battle Cry'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Butter Pecan - Bonus Track', 'artistName': 'YNW Melly', 'albumName': 'Butter Pecan'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Shotta Flow', 'artistName': 'NLE Choppa', 'albumName': 'Shotta Flow'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'PICK IT UP (feat. A$AP Rocky)', 'artistName': 'Famous Dex', 'albumName': 'Pick It Up (feat. A$AP Rocky)'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'No Clue (feat. Lil Yachty)', 'artistName': 'Young Nudy', 'albumName': 'Nudy Land'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Dresser', 'artistName': 'Yung Bans', 'albumName': 'Dresser'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Dedicated', 'artistName': 'YoungBoy Never Broke Again', 'albumName': 'AI YoungBoy'}, 'episode': None, 'localTrack': None}, {'track': {'trackName': "Coastin' (feat. Tk Kravitz)", 'artistName': 'Nebu Kiniza', 'albumName': "Coastin' (feat. Tk Kravitz)"}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Pyrex Kid (feat. Marlo)', 'artistName': 'Lil Gotit', 'albumName': "Crazy But It's True"}, 'episode': None, 'localTrack': None}, {'track': {'trackName': 'Stay "100"', 'artistName': 'Smooky MarGielaa', ' ...

# %%
len(data['playlists'])
# Out:
# 17

# %%
data['playlists'][0]['name']
# Out:
# 'Daily Mix 1 - MADE FOR TJRAIDER23:4/28/19'

# %%
playlist = [x['name'][:17] for x in data['playlists']]
playlist
# Out:
# ['Daily Mix 1 - MAD',
#  'daily bih',
#  'ya feels me',
#  'Ne-Yo ',
#  'Calm',
#  'Music 3',
#  'Spring ',
#  'Music 2',
#  'Music',
#  'Night chill ',
#  'John Mayer',
#  'music',
#  'Roy Woods – Exis',
#  'Running Music',
#  'OVO artist ',
#  'Starred',
#  'chill']

# %%
song = [x['items'][] for x in data['playlists']]
song
# Out:
# [[{'track': {'trackName': 'Barbecue',
#     'artistName': 'Young Nudy',
#     'albumName': 'Nudy Land'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mojo Jojo',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Talk To Big',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'GG',
#     'artistName': 'YoungBoy Never Broke Again',
#     'albumName': 'AI YoungBoy'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Look Like',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Icey',
#     'artistName': 'Young Thug',
#     'albumName': 'On the Run'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Same Yung Nigga (feat. Playboi Carti)',
#     'artistName': 'Gunna',
#     'albumName': 'Drip or Drown 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cracks & Crevices',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Middle Of The Summer (feat. Red Coldhearted)',
#     'artistName': 'Playboi Carti',
#     'albumName': 'Die Lit'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "I'm The Mac",
#     'artistName': 'Lil Yachty',
#     'albumName': "Nuthin' 2 Prove"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Activated',
#     'artistName': 'Tee Grizzley',
#     'albumName': 'Activated'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Givin out Smoke',
#     'artistName': 'Fredo Santana',
#     'albumName': "Trappin' Ain't Dead"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Blank Blank',
#     'artistName': 'DaBaby',
#     'albumName': 'Blank Blank'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Russian Cream',
#     'artistName': 'Key Glock',
#     'albumName': 'Glock Bond'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No More / No Way at All - Interlude',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'White Girl',
#     'artistName': 'Shy Glizzy',
#     'albumName': 'Young Jefe'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ballin'",
#     'artistName': 'Chief Keef',
#     'albumName': 'Finally Rich'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cuttin Up',
#     'artistName': 'Lud Foe',
#     'albumName': 'Cuttin Up'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Battle Cry',
#     'artistName': 'Polo G',
#     'albumName': 'Battle Cry'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Butter Pecan - Bonus Track',
#     'artistName': 'YNW Melly',
#     'albumName': 'Butter Pecan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shotta Flow',
#     'artistName': 'NLE Choppa',
#     'albumName': 'Shotta Flow'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'PICK IT UP (feat. A$AP Rocky)',
#     'artistName': 'Famous Dex',
#     'albumName': 'Pick It Up (feat. A$AP Rocky)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No Clue (feat. Lil Yachty)',
#     'artistName': 'Young Nudy',
#     'albumName': 'Nudy Land'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dresser',
#     'artistName': 'Yung Bans',
#     'albumName': 'Dresser'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dedicated',
#     'artistName': 'YoungBoy Never Broke Again',
#     'albumName': 'AI YoungBoy'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Coastin' (feat. Tk Kravitz)",
#     'artistName': 'Nebu Kiniza',
#     'albumName': "Coastin' (feat. Tk Kravitz)"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pyrex Kid (feat. Marlo)',
#     'artistName': 'Lil Gotit',
#     'albumName': "Crazy But It's True"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stay "100"',
#     'artistName': 'Smooky MarGielaa',
#     'albumName': 'Stay "100"'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Envy Me',
#     'artistName': 'Calboy',
#     'albumName': 'Envy Me'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Here We Go Again',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Look Like',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Play My Song',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dream',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No More / No Way at All - Interlude',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Ocean',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mr. Williams (feat. THEMXXNLIGHT & Curren$y) / Where Is the Love',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Rollin' Like A Stoner",
#     'artistName': 'VIC MENSA',
#     'albumName': 'The Autobiography'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'GUMMO',
#     'artistName': '6ix9ine',
#     'albumName': 'Day69: Graduation Day'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'TESTING'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Diamonds (feat. A$AP Rocky)',
#     'artistName': 'A$AP Twelvyy',
#     'albumName': '12'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pineapple Fanta (feat. Stacy Money Lamont)',
#     'artistName': 'Dirty Shafi',
#     'albumName': 'Pineapple Fanta (feat. Stacy Money Lamont)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'OTW', 'artistName': 'Khalid', 'albumName': 'OTW'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All Of A Sudden',
#     'artistName': 'Lil Baby',
#     'albumName': 'Too Hard'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Kill4u',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cracks & Crevices',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Eazy',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Plastic 100°C',
#     'artistName': 'Sampha',
#     'albumName': 'Process'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Poppa',
#     'artistName': 'Smino',
#     'albumName': 'blkjuptr'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Netflix & Dusse',
#     'artistName': 'Smino',
#     'albumName': 'blkswn'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Monday',
#     'artistName': 'SwagHollywood',
#     'albumName': 'Monday'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Olay',
#     'artistName': 'SwagHollywood',
#     'albumName': 'Welcome To SwooVille'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mojo Jojo',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Activated',
#     'artistName': 'Tee Grizzley',
#     'albumName': 'Activated'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Middle Of The Summer (feat. Red Coldhearted)',
#     'artistName': 'Playboi Carti',
#     'albumName': 'Die Lit'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'GUMMO',
#     'artistName': '6ix9ine',
#     'albumName': 'Day69: Graduation Day'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'TESTING'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Diamonds (feat. A$AP Rocky)',
#     'artistName': 'A$AP Twelvyy',
#     'albumName': '12'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ballin'",
#     'artistName': 'Chief Keef',
#     'albumName': 'Finally Rich'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Talk To Big',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'What Made Me',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pineapple Fanta (feat. Stacy Money Lamont)',
#     'artistName': 'Dirty Shafi',
#     'albumName': 'Pineapple Fanta (feat. Stacy Money Lamont)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6PM In New York',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mob Ties',
#     'artistName': 'Drake',
#     'albumName': 'Scorpion'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Spending Addiction',
#     'artistName': 'Gunna',
#     'albumName': 'Drip Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Hope', 'artistName': 'Jaden', 'albumName': 'SYRE'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Big Body Benz',
#     'artistName': 'Key Glock',
#     'albumName': 'Big Body Benz'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All Of A Sudden',
#     'artistName': 'Lil Baby',
#     'albumName': 'Too Hard'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lust',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Signs of Jealousy',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Strictly Business',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Kill4u',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Only Knew 1 Way',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Purple Ape (feat. 4orever)',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cracks & Crevices',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Marsupial Superstars (feat. T3)',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Eazy',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Plastic 100°C',
#     'artistName': 'Sampha',
#     'albumName': 'Process'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Poppa',
#     'artistName': 'Smino',
#     'albumName': 'blkjuptr'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Netflix & Dusse',
#     'artistName': 'Smino',
#     'albumName': 'blkswn'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Monday',
#     'artistName': 'SwagHollywood',
#     'albumName': 'Monday'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Olay',
#     'artistName': 'SwagHollywood',
#     'albumName': 'Welcome To SwooVille'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Activated',
#     'artistName': 'Tee Grizzley',
#     'albumName': 'Activated'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Nothing',
#     'artistName': 'Teezy Baby',
#     'albumName': 'Nothing'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'through the late night',
#     'artistName': 'Travis Scott',
#     'albumName': 'Birds In The Trap Sing McKnight'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'lose',
#     'artistName': 'Travis Scott',
#     'albumName': 'Birds In The Trap Sing McKnight'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pornography',
#     'artistName': 'Travis Scott',
#     'albumName': 'Rodeo (Expanded Edition)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Antidote',
#     'artistName': 'Travis Scott',
#     'albumName': 'Rodeo (Expanded Edition)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Can Tell',
#     'artistName': 'Travis Scott',
#     'albumName': 'Rodeo (Expanded Edition)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No Smoke No Smoke 1400 B.C. / Sauce',
#     'artistName': 'Trippie Redd',
#     'albumName': 'A Love Letter To You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Check It Out',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mojo Jojo',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Things I Brought',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Rollin' Like A Stoner",
#     'artistName': 'VIC MENSA',
#     'albumName': 'The Autobiography'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Down On My Luck',
#     'artistName': 'VIC MENSA',
#     'albumName': 'Down On My Luck'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Ocean',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mr. Williams (feat. THEMXXNLIGHT & Curren$y) / Where Is the Love',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Fr Fr (feat. Lil Skies)',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dream',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No More / No Way at All - Interlude',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dome (feat. Duke)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'With That (feat. Duke)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Tomorrow 'Til Infinity (feat. Gunna)",
#     'artistName': 'Young Thug',
#     'albumName': 'Beautiful Thugger Girls'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Red Bottom Sky',
#     'artistName': 'Yung Lean',
#     'albumName': 'Stranger'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '20 Years Later',
#     'artistName': 'Yung Pinch',
#     'albumName': '20 Years Later'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Here We Go Again',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Look Like',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Play My Song',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Because Of You',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Crazy',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Can We Chill',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Addicted',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Leaving Tonight',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ain't Thinking About You",
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sex With My Ex',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Angel',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Make It Work',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Say It',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Go On Girl',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stay',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Let Me Get This Right',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'So Sick',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "When You're Mad",
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "It Just Ain't Right",
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mirror',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sign Me Up',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "I Ain't Gotta Tell You",
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Get Down Like That',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sexy Love',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Let Go',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Time',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Get Down Like That - Remix',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Closer',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Nobody',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Single',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mad',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Miss Independent',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Does She Stay',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Fade Into The Background',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'So You Can Cry',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Part Of The List',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Back To What You Know',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lie To Me',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stop This World',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Year Of The Gentleman'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Legend',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Energy',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '10 Bands',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Know Yourself',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "No Tellin'",
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Madonna',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6 God',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Star67',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Preach',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wednesday Night Interlude',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Used To',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6 Man',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Now & Forever',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Company',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'You & The 6',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Jungle',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6PM In New York',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tuscan Leather',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Furthest Thing',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Started From the Bottom',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wu-Tang Forever',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Own It',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Worst Behavior',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'From Time',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Hold On, We're Going Home",
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Connect',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Language',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '305 To My City',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Too Much',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pound Cake / Paris Morton Music 2',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Come Thru',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All Me',
#     'artistName': 'Drake',
#     'albumName': 'Nothing Was The Same'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Vapors',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bed Peace',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stay Ready (What A Life)',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'WTH',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Worst',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3:16AM',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Comfort Inn Ending (Freestyle)',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Intro',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Random',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Me, Myself & I',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'One Of Them (feat. Big Sean)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Drifting (feat. Chris Brown & Tory Lanez)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Of All Things (feat. Too $hort)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Order More (feat. Starrah)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Calm Down',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Don't Let Me Go (feat. SAYGRACE)",
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'You Got Me',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'What If (feat. Gizzle)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sad Boy',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Some Kind Of Drug (feat. Marc E. Bassy)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Think About You (feat. Quiñ)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Everything Will Be OK (feat. Kehlani)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'For This (feat. IAMNOBODI)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Nothing to Me (feat. Keyshia Cole & E-40)',
#     'artistName': 'G-Eazy',
#     'albumName': "When It's Dark Out"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'These Things Happen',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Far Alone (feat. E-40 & Jay Ant)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Mean It (feat. Remo)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Interlude',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Almost Famous',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lotta That (feat. A$AP Ferg & Danny Seth)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Downtown Love (feat. John Michael Rouchell)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Complete',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Let's Get Lost (feat. Devon Baldwin)",
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shoot Me Down (feat. Anthony Stewart)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Been On',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Remember You (feat. Blackbear)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Just Believe',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'No Such Thing',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Georgia',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Stupid Mouth',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Body Is a Wonderland',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Neon',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'City Love',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '83',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3x5',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Song for No One',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Back to You',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Great Indoors',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Not Myself',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "St. Patrick's Day",
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Clarity',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bigger Than My Body',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Something's Missing",
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'New Deep',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Come Back to Bed',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Home Life',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Split Screen Sadness',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Daughters',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Only Heart',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wheel',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Waiting On the World to Change',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "I Don't Trust Myself (With Loving You)",
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Belief',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Gravity',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Heart of Life',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Vultures',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stop This Train',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Slow Dancing in a Burning Room',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bold as Love',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dreaming with a Broken Heart',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'In Repair',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "I'm Gonna Find Another You",
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Say',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Heartbreak Warfare',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All We Ever Do Is Say Goodbye',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Half of My Heart',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Who Says',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Perfectly Lonely',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Assassin',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Crossroads',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'War of My Life',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Edge of Desire',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You Know Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Friends, Lovers or Nothing',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Queen of California',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Age of Worry',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shadow Days',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Speak For Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Something Like Olivia',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Born and Raised',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'If I Ever Get Around To Living',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Is A Verb',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Walt Grace's Submarine Test, January 1967",
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Whiskey, Whiskey, Whiskey',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A Face To Call Home',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Born and Raised - Reprise',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wildfire',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dear Marie',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Waitin' On The Day",
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Paper Doll',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Call Me The Breeze',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Who You Love (feat. Katy Perry)',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Will Be Found (Lost At Sea)',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wildfire (feat. Frank Ocean)',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "You're No One 'Til Someone Lets You Down",
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Badge And Gun',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'On The Way Home',
#     'artistName': 'John Mayer',
#     'albumName': 'Paradise Valley'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'These Things Happen',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Far Alone (feat. E-40 & Jay Ant)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Mean It (feat. Remo)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Interlude',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Almost Famous',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lotta That (feat. A$AP Ferg & Danny Seth)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Downtown Love (feat. John Michael Rouchell)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Complete',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Let's Get Lost (feat. Devon Baldwin)",
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shoot Me Down (feat. Anthony Stewart)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Been On',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Remember You (feat. Blackbear)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Just Believe',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'F Cancer (Boosie) [feat. Quavo]',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Boys (feat. Ralo, Trouble and Lil Durk)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
# ...
#    'localTrack': None},
#   {'track': {'trackName': 'Halftime',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Amazing (feat. Jacquees)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Knocked Off (feat. Birdman)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'OD',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Numbers',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Just Might Be',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'F Cancer (Boosie) [feat. Quavo]',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Boys (feat. Ralo, Trouble and Lil Durk)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'For My People (feat. Duke)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'King TROUP',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ridin' (feat. Lil Durk)",
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Hercules',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Special (feat. Offset and Solo Lucci)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bread Winners (feat. Young Butta)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Family (feat. Dora and Dolly)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'With Them',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Memo',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Drippin'",
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Slime Shit (feat. Yak Gotti, Duke & Peewee Roscoe)',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Digits',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Worth It',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tattoos',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Problem',
#     'artistName': 'Young Thug',
#     'albumName': 'Slime Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Neighborhood',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A Milli Billi Trilli',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Everything I Know',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'BFF',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Feel Like',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Goat',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Halo (Letter From My Unborn Son)',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Big Meech Era',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Starter Kit',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "If I Didn't Rap",
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'El Chapo Jr',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lapdance In The Trap House',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Each & Erry One Of Em',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Blue Dolphin',
#     'artistName': '2 Chainz',
#     'albumName': 'TrapAvelli Tre'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Safe House',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Banned from TV',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Super Saiyan',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '7AM',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Yamborghini Dream (feat. Young Thug)',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Right Now',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Top',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All My Chains',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Belly',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Enemies',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Ballin',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Paradise',
#     'artistName': 'Lil Uzi Vert',
#     'albumName': 'Luv Is Rage'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Run It Up',
#     'artistName': 'Jose Guapo',
#     'albumName': 'Run It Up'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Like Me',
#     'artistName': 'Lil Durk',
#     'albumName': 'Like Me'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'L$D',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'West Side Highway (feat. James Fauntleroy)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I. The Worst Guys',
#     'artistName': 'Childish Gambino',
#     'albumName': 'Because The Internet'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'II. Shadows',
#     'artistName': 'Childish Gambino',
#     'albumName': 'Because The Internet'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Heart Sounds Like',
#     'artistName': 'Fhin',
#     'albumName': 'A Crack in the Eyes'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bed Peace',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'WTH',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You Know Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Whiskey, Whiskey, Whiskey',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stop This Train',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Clarity',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3x5',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '83',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Georgia',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Water',
#     'artistName': 'Lay Coast',
#     'albumName': 'Water'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Lord Willin'",
#     'artistName': 'Logic',
#     'albumName': 'The Incredible True Story'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Make It Work',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Day and Night',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'King City',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Her',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'U',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A Place Like This',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Waves - Robin Schulz Radio Edit',
#     'artistName': 'Mr. Probz',
#     'albumName': 'Waves'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Diddy Bop (feat. Cam O'bi & Raury)",
#     'artistName': 'Noname',
#     'albumName': 'Telefone'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'White Iverson',
#     'artistName': 'Post Malone',
#     'albumName': 'White Iverson'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tell Me Baby',
#     'artistName': 'Red Hot Chili Peppers',
#     'albumName': 'Stadium Arcadium'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Hard to Concentrate',
#     'artistName': 'Red Hot Chili Peppers',
#     'albumName': 'Stadium Arcadium'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Drama (feat. Drake)',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Get You Good',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Down Girl',
#     'artistName': 'Roy Woods',
#     'albumName': 'Waking at Dawn'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Keep'n It Real",
#     'artistName': 'Shaggy',
#     'albumName': 'Hot Shot'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Rinse',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sway',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Paradise',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Race',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "She's American",
#     'artistName': 'The 1975',
#     'albumName': 'I like it when you sleep, for you are so beautiful yet so unaware of it'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Somebody Else',
#     'artistName': 'The 1975',
#     'albumName': 'I like it when you sleep, for you are so beautiful yet so unaware of it'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Loving Someone',
#     'artistName': 'The 1975',
#     'albumName': 'I like it when you sleep, for you are so beautiful yet so unaware of it'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Buried Alive',
#     'artistName': 'Logic',
#     'albumName': 'Under Pressure'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Metropolis',
#     'artistName': 'Logic',
#     'albumName': 'Under Pressure'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dang! (feat. Anderson .Paak)',
#     'artistName': 'Mac Miller',
#     'albumName': 'The Divine Feminine'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pretty Baby',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Same Dude',
#     'artistName': 'Yuri Joness',
#     'albumName': 'Same Dude'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pain (feat. OverDoz.)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'LONG.LIVE.A$AP (Deluxe Version)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'LVL',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'LONG.LIVE.A$AP (Deluxe Version)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Peace Sign',
#     'artistName': 'Rick Ross',
#     'albumName': 'Black Market'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Because Of You',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'So Sick',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Patient',
#     'artistName': 'Post Malone',
#     'albumName': 'Patient'},
#    'episode': None,
#    'localTrack': None}]]

# %%
artist = [x['items'][:17]('artistName') for x in data['playlists']]
artist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1fd18df41c90> in <module>
# ----> 1 artist = [x['items'][:17]('artistName') for x in data['playlists']]
#       2 artist
#
# <ipython-input-21-1fd18df41c90> in <listcomp>(.0)
# ----> 1 artist = [x['items'][:17]('artistName') for x in data['playlists']]
#       2 artist
#
# TypeError: 'list' object is not callable

# %%
data_df = pd.DataFrame({'playlist' : playlist, 'song' : song})
data_df
# Out:
#              playlist                                               song
# 0   Daily Mix 1 - MAD  [{'track': {'trackName': 'Barbecue', 'artistNa...
# 1           daily bih  [{'track': {'trackName': 'Look Like', 'artistN...
# 2         ya feels me  [{'track': {'trackName': 'GUMMO', 'artistName'...
# 3              Ne-Yo   [{'track': {'trackName': 'Because Of You', 'ar...
# 4                Calm  [{'track': {'trackName': 'Legend', 'artistName...
# 5             Music 3  [{'track': {'trackName': 'No Such Thing', 'art...
# 6             Spring   [{'track': {'trackName': 'These Things Happen'...
# 7             Music 2  [{'track': {'trackName': 'All We Need', 'artis...
# 8               Music  [{'track': {'trackName': 'No Such Thing', 'art...
# 9        Night chill   [{'track': {'trackName': 'Tumblr Girls (feat. ...
# 10         John Mayer  [{'track': {'trackName': 'Queen of California'...
# 11              music  [{'track': {'trackName': 'Like Me', 'artistNam...
# 12   Roy Woods – Exis  [{'track': {'trackName': 'Innocence', 'artistN...
# 13      Running Music  [{'track': {'trackName': '417', 'artistName': ...
# 14        OVO artist   [{'track': {'trackName': 'My Love (feat. Drake...
# 15            Starred  [{'track': {'trackName': 'Like Me', 'artistNam...
# 16              chill  [{'track': {'trackName': 'L$D', 'artistName': ...

# %%
artistName = [x['title'][:15] for x in likes['likes_media_likes']]
accounts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-0c1e6650f618> in <module>
# ----> 1 spotify_s_df = pd.DataFrame({'artistName' : artistName, 'trackName' : trackName, 'msPlayed' : msPlayed})
#       2 spotify_s_df
#
# NameError: name 'artistName' is not defined
