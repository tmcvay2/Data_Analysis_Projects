# %% [markdown]
# # Spotify Playlist Artist Count
#
# ## Tovin McVay Jr

# %% [markdown]
# <img src = "SL.jpg"/>

# %% [markdown]
# ### Overview
#
# In the report I will be looking at all of my created music playlist for Spotify. The question I am wanting to answer is, how many times does a certain artist show up in each of my playlist to see who are my top artist I listen to.

# %% [markdown]
# ### Data
#
# For this report, I was able to download my spotify data and retrieve all of my playlist that have been created since using Spotify and see all the songs and artist in each playlist. In this report I will be using json, pandas, matplotlib, and numpy. Below in Lines 1 and 2 I am loadind in my first two packages and loading in my data.

# %%
import json
import pandas as pd
import os

# %%
f = open(os.path.expanduser("~/Desktop/Python/my_spotify_data/MyData/Playlist1.json"))

data = json.load(f)
#data

# %% [markdown]
# Above is my dataset, we can see it has an enormous about of songs and artist, the strings that we will be using are "items, track, name, artistname, albumName, and playlist" to help call out what we want to pull out of the data set.

# %%
len(data['playlists'])
# Out:
# 17

# %% [markdown]
# Here are I requested to see the total number of playlist that are in this file and we can see above that there are 17 different playlist that I have Spotify.

# %%
data['playlists'][0]['name']
# Out:
# 'Daily Mix 1 - MADE FOR TJRAIDER23:4/28/19'

# %% [markdown]
# Above is the 0th element of the data which is the first playlist in the list.

# %%
playlist = [x['name'][:17] for x in data['playlists']]
playlist
# Out:
# ['Daily Mix 1 - MAD',
#  'daily bih',
#  'ya feels me',
#  'Ne-Yo ',
#  'Calm',
#  'Music 3',
#  'Spring ',
#  'Music 2',
#  'Music',
#  'Night chill ',
#  'John Mayer',
#  'music',
#  'Roy Woods – Exis',
#  'Running Music',
#  'OVO artist ',
#  'Starred',
#  'chill']

# %%
song = [x['items'][:17] for x in data['playlists']]
song
# Out:
# [[{'track': {'trackName': 'Barbecue',
#     'artistName': 'Young Nudy',
#     'albumName': 'Nudy Land'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mojo Jojo',
#     'artistName': 'UnoTheActivist',
#     'albumName': 'Live.Shyne.Die'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Talk To Big',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'GG',
#     'artistName': 'YoungBoy Never Broke Again',
#     'albumName': 'AI YoungBoy'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Look Like',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Icey',
#     'artistName': 'Young Thug',
#     'albumName': 'On the Run'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Same Yung Nigga (feat. Playboi Carti)',
#     'artistName': 'Gunna',
#     'albumName': 'Drip or Drown 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cracks & Crevices',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Middle Of The Summer (feat. Red Coldhearted)',
#     'artistName': 'Playboi Carti',
#     'albumName': 'Die Lit'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "I'm The Mac",
#     'artistName': 'Lil Yachty',
#     'albumName': "Nuthin' 2 Prove"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Activated',
#     'artistName': 'Tee Grizzley',
#     'albumName': 'Activated'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Givin out Smoke',
#     'artistName': 'Fredo Santana',
#     'albumName': "Trappin' Ain't Dead"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Blank Blank',
#     'artistName': 'DaBaby',
#     'albumName': 'Blank Blank'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Russian Cream',
#     'artistName': 'Key Glock',
#     'albumName': 'Glock Bond'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No More / No Way at All - Interlude',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'White Girl',
#     'artistName': 'Shy Glizzy',
#     'albumName': 'Young Jefe'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ballin'",
#     'artistName': 'Chief Keef',
#     'albumName': 'Finally Rich'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Look Like',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Play My Song',
#     'artistName': 'Yung Pinch',
#     'albumName': '714Ever'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Dream',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'No More / No Way at All - Interlude',
#     'artistName': 'YFN Lucci',
#     'albumName': 'Ray Ray from Summerhill'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Ocean',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mr. Williams (feat. THEMXXNLIGHT & Curren$y) / Where Is the Love',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers 2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Rollin' Like A Stoner",
#     'artistName': 'VIC MENSA',
#     'albumName': 'The Autobiography'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'GUMMO',
#     'artistName': '6ix9ine',
#     'albumName': 'Day69: Graduation Day'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'TESTING'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Diamonds (feat. A$AP Rocky)',
#     'artistName': 'A$AP Twelvyy',
#     'albumName': '12'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pineapple Fanta (feat. Stacy Money Lamont)',
#     'artistName': 'Dirty Shafi',
#     'albumName': 'Pineapple Fanta (feat. Stacy Money Lamont)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'OTW', 'artistName': 'Khalid', 'albumName': 'OTW'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All Of A Sudden',
#     'artistName': 'Lil Baby',
#     'albumName': 'Too Hard'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Kill4u',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cracks & Crevices',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Eazy',
#     'artistName': 'SahBabii',
#     'albumName': 'S.A.N.D.A.S.'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Plastic 100°C',
#     'artistName': 'Sampha',
#     'albumName': 'Process'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'GUMMO',
#     'artistName': '6ix9ine',
#     'albumName': 'Day69: Graduation Day'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'TESTING'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Diamonds (feat. A$AP Rocky)',
#     'artistName': 'A$AP Twelvyy',
#     'albumName': '12'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ballin'",
#     'artistName': 'Chief Keef',
#     'albumName': 'Finally Rich'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Talk To Big',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'What Made Me',
#     'artistName': 'Dave East',
#     'albumName': 'P2'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pineapple Fanta (feat. Stacy Money Lamont)',
#     'artistName': 'Dirty Shafi',
#     'albumName': 'Pineapple Fanta (feat. Stacy Money Lamont)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6PM In New York',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mob Ties',
#     'artistName': 'Drake',
#     'albumName': 'Scorpion'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Spending Addiction',
#     'artistName': 'Gunna',
#     'albumName': 'Drip Season 3'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Hope', 'artistName': 'Jaden', 'albumName': 'SYRE'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Big Body Benz',
#     'artistName': 'Key Glock',
#     'albumName': 'Big Body Benz'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All Of A Sudden',
#     'artistName': 'Lil Baby',
#     'albumName': 'Too Hard'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lust',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Signs of Jealousy',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Strictly Business',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Kill4u',
#     'artistName': 'Lil Skies',
#     'albumName': 'Life of a Dark Rose'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Because Of You',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Crazy',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Can We Chill',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Addicted',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Leaving Tonight',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Ain't Thinking About You",
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sex With My Ex',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Angel',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Make It Work',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Say It',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Go On Girl',
#     'artistName': 'Ne-Yo',
#     'albumName': 'Because Of You'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stay',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Let Me Get This Right',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'So Sick',
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "When You're Mad",
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "It Just Ain't Right",
#     'artistName': 'Ne-Yo',
#     'albumName': 'In My Own Words'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Legend',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Energy',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '10 Bands',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Know Yourself',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "No Tellin'",
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Madonna',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6 God',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Star67',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Preach',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Wednesday Night Interlude',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Used To',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6 Man',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Now & Forever',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Company',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'You & The 6',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Jungle',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '6PM In New York',
#     'artistName': 'Drake',
#     'albumName': "If You're Reading This It's Too Late"},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'No Such Thing',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Georgia',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Stupid Mouth',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Body Is a Wonderland',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Neon',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'City Love',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '83',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3x5',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Song for No One',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Back to You',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Great Indoors',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Not Myself',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "St. Patrick's Day",
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Clarity',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bigger Than My Body',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Something's Missing",
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'New Deep',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'These Things Happen',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Far Alone (feat. E-40 & Jay Ant)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I Mean It (feat. Remo)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Interlude',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Almost Famous',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lotta That (feat. A$AP Ferg & Danny Seth)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Downtown Love (feat. John Michael Rouchell)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Complete',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Let's Get Lost (feat. Devon Baldwin)",
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shoot Me Down (feat. Anthony Stewart)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Been On',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Remember You (feat. Blackbear)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Just Believe',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'F Cancer (Boosie) [feat. Quavo]',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Boys (feat. Ralo, Trouble and Lil Durk)',
#     'artistName': 'Young Thug',
#     'albumName': "I'm Up"},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'All We Need',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Revolution',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Forbidden Knowledge (feat. Big K.R.I.T.)',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Woodcrest Manor II',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'CPU (feat. RZA)',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Devil's Whisper",
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Peace Prevail',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Crystal Express',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love is Not a Four Letter Word',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Her',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Trap Tears (feat. Key!)',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Mama',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Kingdom Come',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Friends (feat. Tom Morello)',
#     'artistName': 'Raury',
#     'albumName': 'All We Need'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Constantly Hating (feat. Birdman)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'With That (feat. Duke)',
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Can't Tell (feat. T.I. and Boosie BadAzz)",
#     'artistName': 'Young Thug',
#     'albumName': 'Barter 6'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'No Such Thing',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Georgia',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Stupid Mouth',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Body Is a Wonderland',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Neon',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'City Love',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '83',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3x5',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Song for No One',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Back to You',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Great Indoors',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Not Myself',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "St. Patrick's Day",
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Clarity',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bigger Than My Body',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Something's Missing",
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'New Deep',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'King City',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Interlude',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'West Side Highway (feat. James Fauntleroy)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A Place Like This',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Her',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'L$D',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You Know Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Get You Good',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Waves - Robin Schulz Radio Edit',
#     'artistName': 'Mr. Probz',
#     'albumName': 'Waves'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Heart Sounds Like',
#     'artistName': 'Fhin',
#     'albumName': 'A Crack in the Eyes'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Race',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'WTH',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'LVL',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'LONG.LIVE.A$AP (Deluxe Version)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Day and Night',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Whiskey, Whiskey, Whiskey',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Queen of California',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Age of Worry',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shadow Days',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Speak For Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Something Like Olivia',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Born and Raised',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'If I Ever Get Around To Living',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Is A Verb',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Walt Grace's Submarine Test, January 1967",
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Whiskey, Whiskey, Whiskey',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'A Face To Call Home',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Born and Raised - Reprise',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Heartbreak Warfare',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All We Ever Do Is Say Goodbye',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Half of My Heart',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Who Says',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Perfectly Lonely',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Like Me',
#     'artistName': 'Lil Durk',
#     'albumName': 'Like Me'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Innocence',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Go Go Go',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Unleashed',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Get You Good',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Drama (feat. Drake)',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Jealousy',
#     'artistName': 'Roy Woods',
#     'albumName': 'Exis'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Love (feat. Drake) - Remix',
#     'artistName': 'Majid Jordan',
#     'albumName': 'My Love (feat. Drake)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Learn from Each Other',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Make It Work',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Love (feat. Drake)',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Small Talk',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pacifico',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shake Shake Shake',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Is Always There',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Warm',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Something About You',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Day and Night',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': '417',
#     'artistName': 'Lay Coast',
#     'albumName': '417'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Jungle',
#     'artistName': 'Lay Coast',
#     'albumName': 'Jungle'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Cali',
#     'artistName': 'Lay Coast',
#     'albumName': 'Cali'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Water',
#     'artistName': 'Lay Coast',
#     'albumName': 'Water'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Heart Sounds Like',
#     'artistName': 'Fhin',
#     'albumName': 'A Crack in the Eyes'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Waves - Robin Schulz Radio Edit',
#     'artistName': 'Mr. Probz',
#     'albumName': 'Waves'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'The Race',
#     'artistName': 'Wiz Khalifa',
#     'albumName': 'Rolling Papers'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Rinse',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Sway',
#     'artistName': 'Vanessa Carlton',
#     'albumName': 'Be Not Nobody'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Froze',
#     'artistName': 'King Steez',
#     'albumName': 'I Can Do This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': "Lord Willin'",
#     'artistName': 'Logic',
#     'albumName': 'The Incredible True Story'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Day and Night',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'King City',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'White Iverson',
#     'artistName': 'Post Malone',
#     'albumName': 'White Iverson'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Automatic',
#     'artistName': 'DON BROCO',
#     'albumName': 'Automatic'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'My Love (feat. Drake) - Remix',
#     'artistName': 'Majid Jordan',
#     'albumName': 'My Love (feat. Drake)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Learn from Each Other',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Make It Work',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'My Love (feat. Drake)',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Small Talk',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Pacifico',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Shake Shake Shake',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Love Is Always There',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Warm',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Something About You',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Day and Night',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'King City',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Every Step Every Way',
#     'artistName': 'Majid Jordan',
#     'albumName': 'Majid Jordan'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Forever',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'All I Do',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Her',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'U',
#     'artistName': 'Majid Jordan',
#     'albumName': 'A Place Like This'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'Like Me',
#     'artistName': 'Lil Durk',
#     'albumName': 'Like Me'},
#    'episode': None,
#    'localTrack': None}],
#  [{'track': {'trackName': 'L$D',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'West Side Highway (feat. James Fauntleroy)',
#     'artistName': 'A$AP Rocky',
#     'albumName': 'AT.LONG.LAST.A$AP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'I. The Worst Guys',
#     'artistName': 'Childish Gambino',
#     'albumName': 'Because The Internet'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'II. Shadows',
#     'artistName': 'Childish Gambino',
#     'albumName': 'Because The Internet'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Your Heart Sounds Like',
#     'artistName': 'Fhin',
#     'albumName': 'A Crack in the Eyes'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Tumblr Girls (feat. Christoph Andersson)',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Opportunity Cost',
#     'artistName': 'G-Eazy',
#     'albumName': 'These Things Happen'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Bed Peace',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'WTH',
#     'artistName': 'Jhené Aiko',
#     'albumName': 'Sail Out'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Do You Know Me',
#     'artistName': 'John Mayer',
#     'albumName': 'Battle Studies'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Whiskey, Whiskey, Whiskey',
#     'artistName': 'John Mayer',
#     'albumName': 'Born and Raised'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Stop This Train',
#     'artistName': 'John Mayer',
#     'albumName': 'Continuum'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Clarity',
#     'artistName': 'John Mayer',
#     'albumName': 'Heavier Things'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '3x5',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': '83',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Why Georgia',
#     'artistName': 'John Mayer',
#     'albumName': 'Room For Squares'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Water',
#     'artistName': 'Lay Coast',
#     'albumName': 'Water'},
#    'episode': None,
#    'localTrack': None}]]

# %% [markdown]
# The above two lines are me playing around with the data set to see what songs and are in each playlist as well as what are all the name of the 17 playlist on my Spotify,

# %%
data_df = pd.DataFrame({'playlist' : playlist, 'song' : song})
data_df
# Out:
#              playlist                                               song
# 0   Daily Mix 1 - MAD  [{'track': {'trackName': 'Barbecue', 'artistNa...
# 1           daily bih  [{'track': {'trackName': 'Look Like', 'artistN...
# 2         ya feels me  [{'track': {'trackName': 'GUMMO', 'artistName'...
# 3              Ne-Yo   [{'track': {'trackName': 'Because Of You', 'ar...
# 4                Calm  [{'track': {'trackName': 'Legend', 'artistName...
# 5             Music 3  [{'track': {'trackName': 'No Such Thing', 'art...
# 6             Spring   [{'track': {'trackName': 'These Things Happen'...
# 7             Music 2  [{'track': {'trackName': 'All We Need', 'artis...
# 8               Music  [{'track': {'trackName': 'No Such Thing', 'art...
# 9        Night chill   [{'track': {'trackName': 'Tumblr Girls (feat. ...
# 10         John Mayer  [{'track': {'trackName': 'Queen of California'...
# 11              music  [{'track': {'trackName': 'Like Me', 'artistNam...
# 12   Roy Woods – Exis  [{'track': {'trackName': 'Innocence', 'artistN...
# 13      Running Music  [{'track': {'trackName': '417', 'artistName': ...
# 14        OVO artist   [{'track': {'trackName': 'My Love (feat. Drake...
# 15            Starred  [{'track': {'trackName': 'Like Me', 'artistNam...
# 16              chill  [{'track': {'trackName': 'L$D', 'artistName': ...

# %% [markdown]
# The above line I was able to display a small datafram just to show the top track of each playlist that is on my Spotify. This is not the final the result but is very close to i. Now I need to make a table with the artist name and the count.

# %%
data_df['song'][0][0]['track']['artistName']
# Out:
# 'Young Nudy'

# %% [markdown]
# This line is showing what the top artist is for each playlist. So we can see that I told it to show me the top artist for the first playlist which woudld be the 0th element and so we can the top artist for the first playlist is an artist called Young Nudy. If I wanted to see the ones for the other 16, all I have to do is change the 0 in the brackets to the a number from 0-16.

# %%
data_df['song'][4][4]['track']['artistName']
# Out:
# 'Drake'

# %% [markdown]
# So the example above is my trying to find the top artist for the 5th playlist on my spotify and we see that it is Drake.

# %%
data_df['artistName'] = [x[0]['track']['artistName'] for x in data_df['song']]
data_df
# Out:
#              playlist                                               song  \
# 0   Daily Mix 1 - MAD  [{'track': {'trackName': 'Barbecue', 'artistNa...
# 1           daily bih  [{'track': {'trackName': 'Look Like', 'artistN...
# 2         ya feels me  [{'track': {'trackName': 'GUMMO', 'artistName'...
# 3              Ne-Yo   [{'track': {'trackName': 'Because Of You', 'ar...
# 4                Calm  [{'track': {'trackName': 'Legend', 'artistName...
# 5             Music 3  [{'track': {'trackName': 'No Such Thing', 'art...
# 6             Spring   [{'track': {'trackName': 'These Things Happen'...
# 7             Music 2  [{'track': {'trackName': 'All We Need', 'artis...
# 8               Music  [{'track': {'trackName': 'No Such Thing', 'art...
# 9        Night chill   [{'track': {'trackName': 'Tumblr Girls (feat. ...
# 10         John Mayer  [{'track': {'trackName': 'Queen of California'...
# 11              music  [{'track': {'trackName': 'Like Me', 'artistNam...
# 12   Roy Woods – Exis  [{'track': {'trackName': 'Innocence', 'artistN...
# 13      Running Music  [{'track': {'trackName': '417', 'artistName': ...
# 14        OVO artist   [{'track': {'trackName': 'My Love (feat. Drake...
# 15            Starred  [{'track': {'trackName': 'Like Me', 'artistNam...
# 16              chill  [{'track': {'trackName': 'L$D', 'artistName': ...
#
#       artistName
# 0     Young Nudy
# 1     Yung Pinch
# 2        6ix9ine
# 3          Ne-Yo
# 4          Drake
# 5     John Mayer
# 6         G-Eazy
# 7          Raury
# 8     John Mayer
# 9         G-Eazy
# 10    John Mayer
# 11      Lil Durk
# 12     Roy Woods
# 13     Lay Coast
# 14  Majid Jordan
# 15      Lil Durk
# 16    A$AP Rocky

# %% [markdown]
# Now what I have done is created a dataframe that shows, playlist name, artist name, track name, album name, and the top artist count. We can see the number on the far right shows us the amount of times those top artist for each playlist apears in all of the listed playlist.

# %%
count = 0
for x in data_df['song'][4]:
    artist = x['track']['artistName']
    if (artist == 'Drake'):
        count += 1
print(count)
# Out:
# 17

# %% [markdown]
# The line above shows the algorithm for the table above to figure out how many times a certain artist appears on one of the 17 playlist.

# %%
import numpy as np

# %% [markdown]
# Im importing numpy package

# %%
def artist_counter(playlist, artist):
    count = 0 
    for x in playlist:
        if (x['track']['artistName'] == artist):
            count +=1
    return(count)

# %%
data_df['top_artist_count'] = np.nan

# %%
for i in range(0, len(data_df.index)):
    data_df['top_artist_count'][i] = artist_counter(data_df['song'][i], data_df['artistName'][i])
    data_df
# Out:
# /var/folders/n7/_wh3305x3gvf0lyg6pvxdl_40000gn/T/ipykernel_62200/4034510675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['top_artist_count'][i] = artist_counter(data_df['song'][i], data_df['artistName'][i])

# %% [markdown]
# So the three lines above is me getting ready to setup a visual to display the top artist in each playlist.  The first one is another algorithm that will help us calculate the top artist in all the playlist all at once.

# %%
from matplotlib import pyplot as plt
plt.style.use('dark_background')

# %%
fig, ax0 = plt.subplots(figsize=(20,15))
ax0.bar(data_df[:17]['artistName'], data_df['top_artist_count'])
plt.xticks(rotation =60, color = 'white', fontsize = 20)
plt.xlabel('Artist', fontsize = 20)
plt.yticks( color = 'white', fontsize = 30)
plt.ylabel('Number of artist who show up in playlist', fontsize = 20)
plt.title("Top Artist Count", fontsize = "30", color = "white")
plt.show()

# %% [markdown]
# Finally we have out visual bar grapch and it shows up all of my top artist for each playlist.

# %% [markdown]
# # Conclusion
#
# So in conclusion, Ne-Yo,Drake, John Mayer, and Majid Jordan tie for first place with 17 appearances in each of the playlist they are in. For more explanation on why that is, as of 2020-2021 I really dont use spotify as I did years before and most of these playlist were made around 2015 and 2016 and during that time that when I was listening to those artist the most and I still do these are still my favorite artist. But we can see that Young Nudy, Yung Pinch and Lil Durk are more recent playlist that I have made but when downloading my data, spotify did not include my most recent made playlist and so we were going to see a more of shift to more rap music if those rencent playlist were included, the top artist in these are more of an R&B and chill type music and so the genre shift was at its early stages in this as it included young nudy, lil durk,and pinch who are all hip hop and rap genre.
